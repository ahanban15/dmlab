# %%
import pandas as pd

bikedata = pd.read_csv("seoulbike.csv")
bikedata.fillna(0, inplace = True)
bikedata.info()
bikedata.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147339 entries, 0 to 147338
# Data columns (total 26 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  147339 non-null  int64
#  1   Duration    147339 non-null  int64
#  2   Distance    147339 non-null  int64
#  3   PLong       147339 non-null  float64
#  4   PLatd       147339 non-null  float64
#  5   DLong       147339 non-null  float64
#  6   DLatd       147339 non-null  float64
#  7   Haversine   147339 non-null  float64
#  8   Pmonth      147339 non-null  int64
#  9   Pday        147339 non-null  int64
#  10  Phour       147339 non-null  int64
#  11  Pmin        147339 non-null  int64
#  12  PDweek      147339 non-null  int64
#  13  Dmonth      147339 non-null  int64
#  14  Dday        147339 non-null  int64
#  15  Dhour       147339 non-null  int64
#  16  Dmin        147339 non-null  int64
#  17  DDweek      147339 non-null  int64
#  18  Temp        147339 non-null  float64
#  19  Precip      147339 non-null  float64
#  20  Wind        147339 non-null  float64
#  21  Humid       147339 non-null  float64
#  22  Solar       147339 non-null  float64
#  23  Snow        147339 non-null  float64
#  24  GroundTemp  147339 non-null  float64
#  25  Dust        147339 non-null  float64
# dtypes: float64(13), int64(13)
# memory usage: 29.2 MB
#    Unnamed: 0  Duration  Distance      PLong       PLatd      DLong  \
# 0           0         3        50  37.544666  126.888359  37.544666
# 1           1        24      7670  37.506199  127.003944  37.551250
# 2           2         8      1390  37.544590  127.057083  37.537014
# 3           3         8      1820  37.571102  127.023560  37.561447
# 4           4         4       850  37.573242  127.015907  37.565849
#
#         DLatd  Haversine  Pmonth  Pday  ...  Dmin  DDweek  Temp  Precip  Wind  \
# 0  126.888359   0.000000       1     1  ...     4       0  -3.2     0.0   0.5
# 1  127.035103   5.713529       1     1  ...    25       0  -3.2     0.0   0.5
# 2  127.061096   0.913702       1     1  ...     9       0  -3.2     0.0   0.5
# 3  127.034920   1.468027       1     1  ...    10       0  -3.2     0.0   0.5
# 4  127.016403   0.823227       1     1  ...     6       0  -3.2     0.0   0.5
#
#    Humid  Solar  Snow  GroundTemp  Dust
# 0   40.0    0.0   0.0        -2.2  25.0
# 1   40.0    0.0   0.0        -2.2  25.0
# 2   40.0    0.0   0.0        -2.2  25.0
# 3   40.0    0.0   0.0        -2.2  25.0
# 4   40.0    0.0   0.0        -2.2  25.0
#
# [5 rows x 26 columns]

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.datasets import load_digits


x = bikedata.drop('Duration', axis=1)
y = bikedata['Duration']

train_X, test_X, train_y, test_y = train_test_split(x, y, test_size = 0.25)

gbr = GradientBoostingRegressor()

gbr.fit(train_X, train_y)

pred_y = gbr.predict(test_X)

mse = mean_squared_error(test_y, pred_y)

print(mse)
# Out:
# 125.35543590859871

# %%
import xgboost as xgb

xgb_model = xgb.XGBRegressor()
xgb_model.fit(train_X, train_y)

pred_y = xgb_model.predict(test_X)

mse = mean_squared_error(test_y, pred_y)

print(mse)
# Out:
# 31.534742610021397

# %%
from sklearn.ensemble import AdaBoostRegressor

adaboost = AdaBoostRegressor()

adaboost.fit(train_X, train_y)

pred_y = adaboost.predict(test_X)

mse = mean_squared_error(test_y, pred_y)

print(mse)
