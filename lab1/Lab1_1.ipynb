# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(10)
data = np.random.normal(100, 20, 200)

fig = plt.figure(figsize =(10, 7))

plt.boxplot(data)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import numpy as np
#       4 np.random.seed(10)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib
# Out:
# ...
# DEPRECATION: Loading egg at c:\users\ahan\appdata\local\programs\python\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#      ---------------------------------------- 0.0/160.8 kB ? eta -:--:--
#      ------- -------------------------------- 30.7/160.8 kB ? eta -:--:--
#      -------------- ---------------------- 61.4/160.8 kB 825.8 kB/s eta 0:00:01
#      --------------------------- -------- 122.9/160.8 kB 901.1 kB/s eta 0:00:01
#      -------------------------------- --- 143.4/160.8 kB 944.1 kB/s eta 0:00:01
#      -------------------------------- --- 143.4/160.8 kB 944.1 kB/s eta 0:00:01
#      -------------------------------- --- 143.4/160.8 kB 944.1 kB/s eta 0:00:01
#      -------------------------------- --- 143.4/160.8 kB 944.1 kB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(10)
ahan = np.random.normal(50, 5, 50)

fig = plt.figure(figsize =(5, 5))

plt.boxplot(ahan)

plt.show()
