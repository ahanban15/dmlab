# %% [markdown]
# **HISTOGRAM**

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data for the histogram
data = np.random.randn(1000)

# Plotting a basic histogram
plt.hist(data, bins=10, color='purple', edgecolor='black')

# Adding labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Basic Histogram')

# Display the plot
plt.show()

# %% [markdown]
# **SCATTER PLOT**

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import random

x=random.randint(100, size=(10))
y=random.randint(100, size=(10))
# Plotting a basic scatterplot
plt.scatter(x,y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatterplot')
plt.show()

# %% [markdown]
# **BAR PLOT**

# %%
import numpy as np
import matplotlib.pyplot as plt


# creating the dataset
data = {'C':20, 'C++':15, 'Java':30,
        'Python':35}
courses = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (5,2))

# creating the bar plot
plt.bar(courses, values, color ='purple')

plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Bar Plot")
plt.show()

# %%
import pandas as pd
df=pd.read_csv("/content/train_u6lujuX_CVtuZ9i.csv")

df.describe()

# %%
df.head(4)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y

# %% [markdown]
# **UNIVARIANT**
#
#
# *   Histogram-  Loan amount term

# %%
plt.hist(df.Loan_Amount_Term)
# Out:
# (array([  3.,   6.,   3.,  44.,   4.,   0.,  13., 512.,   0.,  15.]),
#  array([ 12. ,  58.8, 105.6, 152.4, 199.2, 246. , 292.8, 339.6, 386.4,
#         433.2, 480. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# *   Violin Plot -  CoapplicantIncome

# %%
plt.violinplot(df.CoapplicantIncome)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7c75bbf6f250>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7c75bbf6f2b0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7c75bbfe6860>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7c75bbfe44f0>}

# %% [markdown]
# *   Bar Graph -  Gender

# %%
gc=df.Gender.value_counts()
plt.bar(gc.index,gc)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# **BIVARIANT**
#
# *   ScatterPlot - ApplicantIncome and LoanAmount

# %%
plt.scatter(df.ApplicantIncome,df.LoanAmount)

# %% [markdown]
# *   CountPLot - Education

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv("/content/train_u6lujuX_CVtuZ9i.csv")
sns.countplot(x='Education',data=df, color='green', saturation=0.1)
plt.show()

# %% [markdown]
# *   BarPlot - Gender, ApplicantIncome

# %%
sns.barplot(x = 'Gender', y = 'ApplicantIncome', data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='ApplicantIncome'>

# %% [markdown]
# **MULTIVARIENT**
#
# *   HeatMap

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(df.corr(), c7enter=0, annot=True)
# Out:
# <ipython-input-65-5d0c0c46e9c4>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), center=0, annot=True)
# <Axes: >

# %% [markdown]
# *   Bar PLot - Gender, ApplicantIncome,Loan_Status(hue)

# %%
sns.barplot(x = 'Gender', y = 'ApplicantIncome', hue="Loan_Status",data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='ApplicantIncome'>
