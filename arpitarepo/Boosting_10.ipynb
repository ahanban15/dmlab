# %%
import pandas as pd

df = pd.read_csv("For_modeling.csv")
df
# Out:
#        Unnamed: 0  Duration  Distance      PLong       PLatd      DLong  \
# 0               0         3        50  37.544666  126.888359  37.544666
# 1               1        24      7670  37.506199  127.003944  37.551250
# 2               2         8      1390  37.544590  127.057083  37.537014
# 3               3         8      1820  37.571102  127.023560  37.561447
# 4               4         4       850  37.573242  127.015907  37.565849
# ...           ...       ...       ...        ...         ...        ...
# 15654      866771        23      3540  37.575069  126.899918  37.599491
# 15655      866772        31      8260  37.616169  127.093483  37.645802
# 15656      866773        34      6080  37.577316  126.902969  37.620949
# 15657      866774        12      2260  37.577686  127.031013  37.567970
# 15658      866775         4       530  37.488564  126.928482  37.484409
#
#             DLatd  Haversine  Pmonth  Pday  ...  Dmin  DDweek  Temp  Precip  \
# ...

# %%
# !pip install catboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 7.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

columns_to_drop = ['PLong', 'PLatd']

# Drop the specified columns
reduced_df = df.drop(columns=columns_to_drop, inplace = True)
df
# Out:
#        Unnamed: 0  Duration  Distance      DLong       DLatd  Haversine  \
# 0               0         3        50  37.544666  126.888359   0.000000
# 1               1        24      7670  37.551250  127.035103   5.713529
# 2               2         8      1390  37.537014  127.061096   0.913702
# 3               3         8      1820  37.561447  127.034920   1.468027
# 4               4         4       850  37.565849  127.016403   0.823227
# ...           ...       ...       ...        ...         ...        ...
# 15654      866771        23      3540  37.599491  126.916862   3.098962
# 15655      866772        31      8260  37.645802  127.082260   3.440071
# 15656      866773        34      6080  37.620949  126.925636   5.246671
# 15657      866774        12      2260  37.567970  127.046890   1.767799
# 15658      866775         4       530  37.484409  126.928909   0.463549
#
#        Pmonth  Pday  Phour  Pmin  ...  Dmin  DDweek  Temp  Precip  Wind  \
# ...

# %%
columns_to_drop = ['Haversine', 'Pmonth', 'Dmonth',  'DDweek', 'DDweek', 'Humid']

# Drop the specified columns
reduced_df = df.drop(columns=columns_to_drop, inplace = True)
df
# Out:
#        Unnamed: 0  Duration  Distance      DLong       DLatd  Pday  Phour  \
# 0               0         3        50  37.544666  126.888359   1.0    0.0
# 1               1        24      7670  37.551250  127.035103   1.0    0.0
# 2               2         8      1390  37.537014  127.061096   1.0    0.0
# 3               3         8      1820  37.561447  127.034920   1.0    0.0
# 4               4         4       850  37.565849  127.016403   1.0    0.0
# ...           ...       ...       ...        ...         ...   ...    ...
# 15653      866770        21      3520  37.582500  126.998535   4.0   18.0
# 15654      866771        23      3540  37.599491  126.916862   4.0   18.0
# 15655      866772        31      8260  37.645802  127.082260   4.0   18.0
# 15656      866773        34      6080  37.620949  126.925636   4.0   18.0
# 15657      866774        12      2260  37.567970  127.046890   4.0   18.0
#
#        Pmin  PDweek  Dday  Dhour  Dmin  Temp  Precip  Wind  Solar  Snow  \
# ...

# %%
df.dropna(inplace= True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
import xgboost as xgb
import catboost as cb

X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['Duration']), df['Duration'], test_size=0.2, random_state=42)

# Gradient Boosting
gb_model = GradientBoostingClassifier()
gb_model.fit(X_train, y_train)
gb_pred = gb_model.predict(X_test)
gb_accuracy = accuracy_score(y_test, gb_pred)

# XGBoost
xgb_model = xgb.XGBClassifier()
xgb_model.fit(X_train, y_train)
xgb_pred = xgb_model.predict(X_test)
xgb_accuracy = accuracy_score(y_test, xgb_pred)

# AdaBoost
ada_model = AdaBoostClassifier()
ada_model.fit(X_train, y_train)
ada_pred = ada_model.predict(X_test)
ada_accuracy = accuracy_score(y_test, ada_pred)

# CatBoost
cat_model = cb.CatBoostClassifier()
cat_model.fit(X_train, y_train)
cat_pred = cat_model.predict(X_test)
cat_accuracy = accuracy_score(y_test, cat_pred)

# Printing the accuracy of each model
print("Gradient Boosting Accuracy:", gb_accuracy)
print("XGBoost Accuracy:", xgb_accuracy)
print("AdaBoost Accuracy:", ada_accuracy)
print("CatBoost Accuracy:", cat_accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-00cd11f76417> in <cell line: 17>()
#      15 # XGBoost
#      16 xgb_model = xgb.XGBClassifier()
# ---> 17 xgb_model.fit(X_train, y_train)
#      18 xgb_pred = xgb_model.predict(X_test)
#      19 xgb_accuracy = accuracy_score(y_test, xgb_pred)
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     728             for k, arg in zip(sig.parameters, args):
#     729                 kwargs[k] = arg
# --> 730             return func(**kwargs)
#     731
#     732         return inner_f
#
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
# ...
